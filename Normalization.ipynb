# %% [markdown]
# # Normalization (Using Min-Max Scaling)

# %% [markdown]
# To deal with outliers we should do Normalization firstly.

# %% [markdown]
# This is the approach where we will scale down the values of the features between 0 and 1.

# %% [markdown]
# Formulae Xnorm = X-Xmin / Xmax-Xmin

# %%
import pandas as pd
import seaborn as sbn

# %%
df=pd.read_csv(r'C:\Users\TARUN\Desktop\Tarun\Data Science\Machine Learning\Data Pre-Processing\Feature Scaling\Min Max Data Set.csv')

# %%
df.columns=['class','alcohol','malic']
df.head()
# Out:
#   class  alcohol  malic
# 0     I     10.0   8.04
# 1     I      8.0   6.95
# 2     I     13.0   7.58
# 3     I      9.0   8.81
# 4     I     11.0   8.33

# %% [markdown]
# # Alcohol Column Before & After Normalization

# %%
from IPython.display import Image
Image(filename='Alcohol Before Normalization.png')

# %%
from IPython.display import Image
Image(filename='Alcohol After Normalization.png')

# %% [markdown]
# # Malic Column Before & After Normalization

# %%
from IPython.display import Image
Image(filename='Malic Before Normalization.png')

# %%
from IPython.display import Image
Image(filename='Malic After Normalization.png')

# %% [markdown]
# # Visualizing Columns

# %%
sbn.distplot(df['alcohol'])
# Out:
# C:\Users\TARUN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
sbn.distplot(df['malic'])
# Out:
# C:\Users\TARUN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='malic', ylabel='Density'>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaling=MinMaxScaler()

# %%
df=scaling.fit_transform(df[['alcohol','malic']])

# %%
df
# Out:
# array([[0.4       , 0.51244813],
#        [0.26666667, 0.39937759],
#        [0.6       , 0.46473029],
#        [0.33333333, 0.59232365],
#        [0.46666667, 0.54253112],
#        [0.66666667, 0.71161826],
#        [0.13333333, 0.42946058],
#        [0.        , 0.12033195],
#        [0.53333333, 0.80290456],
#        [0.2       , 0.17842324],
#        [0.06666667, 0.26763485],
#        [0.4       , 0.62655602],
#        [0.26666667, 0.52282158],
#        [0.6       , 0.58506224],
#        [0.33333333, 0.58817427],
#        [0.46666667, 0.63900415],
#        [0.66666667, 0.5186722 ],
#        [0.13333333, 0.31431535],
#        [0.        , 0.        ],
#        [0.53333333, 0.62551867],
#        [0.2       , 0.43153527],
#        [0.06666667, 0.17012448],
#        [0.4       , 0.45228216],
#        [0.26666667, 0.38070539],
#        [0.6       , 1.        ],
#        [0.33333333, 0.4159751 ],
#        [0.46666667, 0.48858921],
#        [0.66666667, 0.59543568],
# ...

# %%
df=pd.DataFrame(df)
df.head()
# Out:
#           0         1
# 0  0.400000  0.512448
# 1  0.266667  0.399378
# 2  0.600000  0.464730
# 3  0.333333  0.592324
# 4  0.466667  0.542531

# %%
df.columns=['alcohol','malic']
df.head()
# Out:
#     alcohol     malic
# 0  0.400000  0.512448
# 1  0.266667  0.399378
# 2  0.600000  0.464730
# 3  0.333333  0.592324
# 4  0.466667  0.542531

# %%
sbn.distplot(df['alcohol'])
# Out:
# C:\Users\TARUN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
sbn.distplot(df['malic'])
# Out:
# C:\Users\TARUN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='malic', ylabel='Density'>

# %% [markdown]
# # Performing Normalize

# %%
df=pd.read_csv(r'C:\Users\TARUN\Desktop\Tarun\Data Science\Machine Learning\Data Pre-Processing\Feature Scaling\Min Max Data Set.csv')

# %%
df.columns=['class','alcohol','malic']
df.head()
# Out:
#   class  alcohol  malic
# 0     I     10.0   8.04
# 1     I      8.0   6.95
# 2     I     13.0   7.58
# 3     I      9.0   8.81
# 4     I     11.0   8.33

# %%
import sklearn
from sklearn import preprocessing 
normalized_x = preprocessing.normalize(df[['alcohol','malic']])
normalized_x
# Out:
# array([[0.77934582, 0.62659404],
#        [0.75491017, 0.65582821],
#        [0.86387529, 0.50370575],
#        [0.71460965, 0.69952344],
#        [0.79720841, 0.60370419],
#        [0.81483314, 0.57969557],
#        [0.63808993, 0.76996185],
#        [0.68451016, 0.72900332],
#        [0.74206295, 0.6703302 ],
#        [0.82362974, 0.5671279 ],
#        [0.66074705, 0.75060865],
#        [0.73813383, 0.67465432],
#        [0.7009469 , 0.71321347],
#        [0.82988334, 0.55793695],
#        [0.71619899, 0.69789613],
#        [0.7650194 , 0.64400724],
#        [0.86556735, 0.50079254],
#        [0.69948839, 0.71464397],
#        [0.79041505, 0.61257167],
#        [0.79584259, 0.60550357],
#        [0.69409887, 0.71987968],
#        [0.7257238 , 0.68798616],
#        [0.80153632, 0.59794609],
#        [0.76335009, 0.64598501],
#        [0.71421284, 0.69992858],
#        [0.78468187, 0.61989868],
#        [0.81538298, 0.57892192],
#        [0.8455463 , 0.5339021 ],
# ...

# %%
df=pd.DataFrame(normalized_x)

# %%
df.columns=['alcohol','malic']
df.head()
# Out:
#     alcohol     malic
# 0  0.779346  0.626594
# 1  0.754910  0.655828
# 2  0.863875  0.503706
# 3  0.714610  0.699523
# 4  0.797208  0.603704
